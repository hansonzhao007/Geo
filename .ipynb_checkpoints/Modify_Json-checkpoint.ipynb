# %%
import json
from pprint import pprint

file="GeojsonGraphData/nyu_nodes_ways_relations.json"

data = json.load(open(file))

pprint(data)
# Out:
# {'features': [{'geometry': {'coordinates': [[-73.98676300048828,
#                                              40.67280197143555],
#                                             [-73.98726654052734,
#                                              40.67219543457031],
#                                             [-73.98764038085938,
#                                              40.671749114990234]],
#                             'type': 'LineString'},
#                'properties': {'class': 'NWRWay',
#                               'hgv': 'local',
#                               'highway': 'primary',
#                               'id': 420346484,
#                               'name': '4th Avenue',
#                               'network': 'lcn',
#                               'oneway': 'yes',
#                               'route': 'bicycle'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [[-73.97232818603516,
# ...

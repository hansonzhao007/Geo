# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.ndimage as sp
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from astropy.io import fits
from astropy.table import Table
from astropy.table import Column
from astropy.convolution import convolve, Gaussian2DKernel

# %matplotlib inline
data = pd.read_csv('./motivation-sdc-cache-40K.txt',header=None)
data.columns = ['x','y']
x = data['x'].values.tolist()
y = data['y'].values.tolist()
x_lim = (min(x), max(x))
y_lim = (min(y), max(y))
print("x range:",x_lim)
print("y range:",y_lim)
heatmap, xedges, yedges = np.histogram2d(x, y, bins=50)
# print(heatmap)
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
# print(extent)

# plt.imshow(
#     convolve(heatmap, Gaussian2DKernel(x_stddev=6)),
#     extent=extent,
#     interpolation='none',
#     aspect="auto",
#     #cmap=cm.hot,
#     #norm=LogNorm()
# )
# plt.colorbar()
# plt.show()

data.groupby(['x','y'])['x'].count().to_csv("res.csv")
# Out:
# x range: (0, 16382)
# y range: (0, 7)

# %%
df = pd.DataFrame(data, columns=["x", "y"])
sns.jointplot(x="x", y="y", data=df, kind="kde");

# %%
f, ax = plt.subplots(figsize=(6, 6))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0.2, light=1, reverse=True)
sns.kdeplot(df.x, df.y, cmap=cmap, n_levels=60, shade=True);

# %%
with sns.axes_style("white"):
    sns.jointplot(x=np.asarray(x), y=np.asarray(y), kind="hex", color="k");

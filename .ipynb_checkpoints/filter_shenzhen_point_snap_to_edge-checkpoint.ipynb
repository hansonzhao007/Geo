# %%
import folium
from folium import plugins
import pandas as pd
import random
import json
# latitude, longitude
location = [22.618864, 114.027283]
m = folium.Map(location,tiles='Stamen Toner', zoom_start=11)

# %%
geo = r'GeojsonGraphData/shenzhen_point_link_edge.json'

#Let Folium determine the scale
roads = folium.GeoJson(
    geo,
    style_function=lambda feature: {
        'fillColor': '#00ff00',
        'color': 'red',
        'weight': 2,
        'dashArray': '5, 5',
        'fillOpacity': 0.5,
    }
)
m.add_child(roads)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
geo = r'GeojsonGraphData/filter_shenzhen_taxi.json'
with open(geo) as f:
        data = json.load(f)
df = []
for feature in data['features']:
    df.append(feature["geometry"]["coordinates"]);
df = pd.DataFrame(df,columns=['lng','lat']) 
heat_data = [[row['lat'],row['lng']] for index, row in df.iterrows()]

heat_map = plugins.HeatMap(heat_data, 
                           radius = 7,
                           min_opacity = 0.8,
                           blur=2,
                           #max_zoom=1
                          )
m.add_child(heat_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('shenzhen_nearest_edge.html')
